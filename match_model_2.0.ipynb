# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import sys
from IPython.display import Image, display

# %%
df = pd.read_csv('model_comp_labels_2', header=[0,1], index_col=0)

# %%
df
# Out:
#              cave_jolimont                corton             guillaume  \
#                     mobnet      openv     mobnet      openv     mobnet
# 1.0.jpg          59.307164   2.484739  57.733190  21.170086  60.450763
# 10.0.jpg         58.597076   4.408151  58.021176  27.997774  56.287301
# 100.0.png        56.771070  24.063587  64.930212  22.879578  60.385829
# 1000.0.jpg       55.658585  15.455914  70.322657  29.996400  65.277541
# 101.0.jpg        67.167968   9.210169  70.759559   3.731895  63.224870
# ...                    ...        ...        ...        ...        ...
# lacroix.jpg      61.904800  -0.619578  52.460176  41.227210  60.726750
# ladybird.jpg     67.205971  19.548840  64.547867  28.195131  61.547625
# monplezy.jpg     58.526760  -3.667414  55.641419  33.196796  52.705330
# pelican.jpg      54.529750  19.459540  42.710081  15.500689  48.973823
# vistas.jpg       48.533916  23.880910  38.518727   3.572369  43.609518
#
# ...

# %% [markdown]
# # cave_jolimont

# %%
cave_jolimont_test_img_path = 'unpack_archive\\cave_jolimont_test.jpg'
display(Image(cave_jolimont_test_img_path))

# %%
cave_jolimont_img_path = 'unpack_archive\\zip\\cave_jolimont.jpg'
display(Image(cave_jolimont_img_path))

# %%
result_cave_jolimont = pd.concat([df.cave_jolimont.idxmax(), df.cave_jolimont.max()])

# %%
result_cave_jolimont
# Out:
# mobnet    cave_jolimont.jpg
# openv     cave_jolimont.jpg
# mobnet             91.96189
# openv             63.774235
# dtype: object

# %%
df.cave_jolimont.mobnet[df.cave_jolimont.mobnet > 74].sort_values(ascending=False)
# Out:
# cave_jolimont.jpg    91.96189
# 910.0.jpg            74.39000
# Name: mobnet, dtype: float64

# %%
df.cave_jolimont.openv[df.cave_jolimont.openv > 60].sort_values(ascending=False)
# Out:
# cave_jolimont.jpg    63.774235
# 862.0.jpg            61.264503
# Name: openv, dtype: float64

# %%
df.loc['cave_jolimont.jpg'].cave_jolimont
# Out:
# mobnet    91.961890
# openv     63.774235
# Name: cave_jolimont.jpg, dtype: float64

# %% [markdown]
# # corton

# %%
corton_test_img_path = 'unpack_archive\\corton_test.jpg'
display(Image(corton_test_img_path))

# %%
corton_img_path = 'unpack_archive\\zip\\corton.jpg'
display(Image(corton_img_path))

# %%
result_corton = pd.concat([df.corton.idxmax(), df.corton.max()])

# %%
result_corton
# Out:
# mobnet    corton.jpg
# openv     corton.jpg
# mobnet     96.322286
# openv       73.83406
# dtype: object

# %%
df.corton.mobnet[df.corton.mobnet > 80].sort_values(ascending=False)
# Out:
# corton.jpg    96.322286
# 347.0.jpg     80.866009
# 999.0.jpg     80.399191
# 459.0.jpg     80.248821
# 540.0.jpg     80.128688
# Name: mobnet, dtype: float64

# %%
df.corton.openv[df.corton.openv > 70].sort_values(ascending=False)
# Out:
# corton.jpg    73.834060
# 662.0.jpg     71.081690
# 835.0.jpg     70.663216
# Name: openv, dtype: float64

# %%
df.loc['corton.jpg'].corton
# Out:
# mobnet    96.322286
# openv     73.834060
# Name: corton.jpg, dtype: float64

# %% [markdown]
# # guillaume

# %%
guillaume_test_img_path = 'unpack_archive\\guillaume_test.jpg'
display(Image(guillaume_test_img_path))

# %%
guillaume_img_path = 'unpack_archive\\zip\\guillaume.jpg'
display(Image(guillaume_img_path))

# %%
result_guillaume = pd.concat([df.guillaume.idxmax(), df.guillaume.max()])

# %%
df.loc['guillaume.jpg'].guillaume
# Out:
# mobnet    96.559483
# openv     97.008500
# Name: guillaume.jpg, dtype: float64

# %%
df.guillaume.mobnet[df.guillaume.mobnet > 78].sort_values(ascending=False)
# Out:
# guillaume.jpg    96.559483
# 672.0.jpg        79.628050
# 847.0.jpg        78.779870
# 188.0.jpg        78.657454
# Name: mobnet, dtype: float64

# %%
df.guillaume.openv[df.guillaume.openv > 83].sort_values(ascending=False)
# Out:
# guillaume.jpg    97.008500
# 394.0.jpg        86.228386
# 697.0.jpg        83.285164
# Name: openv, dtype: float64

# %% [markdown]
# # HM_Hoffer

# %%
hofer_test_img_path = 'unpack_archive\\hofer_test.png'
display(Image(hofer_test_img_path))

# %%
hofer_img_path = 'unpack_archive\\zip\\hofer.png'
display(Image(hofer_img_path))

# %%
result_hofer = pd.concat([df.hofer.idxmax(), df.hofer.max()])

# %%
df.loc['hofer.png'].hofer
# Out:
# mobnet    97.731453
# openv     78.641365
# Name: hofer.png, dtype: float64

# %%
df.hofer.mobnet[df.hofer.mobnet > 82.5].sort_values(ascending=False)
# Out:
# hofer.png    97.731453
# 282.0.jpg    84.490937
# 468.0.jpg    82.957846
# 535.0.jpg    82.893205
# 662.0.jpg    82.861644
# Name: mobnet, dtype: float64

# %%
df.hofer.openv[df.hofer.openv > 58.4].sort_values(ascending=False)
# Out:
# hofer.png    78.641365
# 205.0.jpg    59.347450
# 655.0.jpg    58.735676
# Name: openv, dtype: float64

# %% [markdown]
# # lacroix

# %%
lacroix_test_img_path = 'unpack_archive\\lacroix_test.jpg'
display(Image(lacroix_test_img_path))

# %%
lacroix_img_path = 'unpack_archive\\zip\\lacroix.jpg'
display(Image(lacroix_img_path))

# %%
result_lacroix = pd.concat([df.lacroix.idxmax(), df.lacroix.max()])

# %%
df.loc['lacroix.jpg'].lacroix
# Out:
# mobnet    96.067357
# openv     88.784670
# Name: lacroix.jpg, dtype: float64

# %%
df.lacroix.mobnet[df.lacroix.mobnet > 75].sort_values(ascending=False)
# Out:
# lacroix.jpg    96.067357
# 444.0.jpg      75.697982
# Name: mobnet, dtype: float64

# %%
df.lacroix.openv[df.lacroix.openv > 74].sort_values(ascending=False)
# Out:
# lacroix.jpg    88.78467
# Name: openv, dtype: float64

# %% [markdown]
# # ladybird

# %%
ladybird_test_img_path = 'unpack_archive\\ladybird_test.jpg'
display(Image(ladybird_test_img_path))

# %%
ladybird_img_path = 'unpack_archive\\zip\\ladybird.jpg'
display(Image(ladybird_img_path))

# %%
result_ladybird = pd.concat([df.ladybird.idxmax(), df.ladybird.max()])

# %%
df.loc['ladybird.jpg'].ladybird
# Out:
# mobnet    92.911434
# openv     82.836876
# Name: ladybird.jpg, dtype: float64

# %%
df.ladybird.mobnet[df.ladybird.mobnet > 75].sort_values(ascending=False)
# Out:
# ladybird.jpg    92.911434
# 253.0.jpg       77.864355
# 56.0.jpg        76.577246
# 585.0.jpg       76.496333
# 996.0.jpg       75.696456
# 559.0.png       75.630325
# 485.0.jpg       75.139678
# Name: mobnet, dtype: float64

# %%
len(df.ladybird.openv[df.ladybird.openv > 20.92].sort_values(ascending=False))
# Out:
# 171

# %% [markdown]
# # monplezy

# %%
monplezy_test_img_path = 'unpack_archive\\monplezy_test.jpg'
display(Image(monplezy_test_img_path))

# %%
monplezy_img_path = 'unpack_archive\\zip\\monplezy.jpg'
display(Image(monplezy_img_path))

# %%
result_monplezy = pd.concat([df.monplezy.idxmax(), df.monplezy.max()])

# %%
df.loc['monplezy.jpg'].monplezy
# Out:
# mobnet    96.504343
# openv     93.501300
# Name: monplezy.jpg, dtype: float64

# %%
df.monplezy.mobnet[df.monplezy.mobnet > 68].sort_values(ascending=False)
# Out:
# monplezy.jpg    96.504343
# 655.0.jpg       68.816882
# 778.0.png       68.046159
# Name: mobnet, dtype: float64

# %%
df.monplezy.openv[df.monplezy.openv > 75].sort_values(ascending=False)
# Out:
# monplezy.jpg    93.50130
# 876.0.jpg       76.53894
# 20.0.jpg        75.45577
# 269.0.png       75.06542
# Name: openv, dtype: float64

# %% [markdown]
# # pelican

# %%
pelican_test_img_path = 'unpack_archive\\pelican_test.jpg'
display(Image(pelican_test_img_path))

# %%
pelican_img_path = 'unpack_archive\\zip\\pelican.jpg'
display(Image(pelican_img_path))

# %%
result_pelican = pd.concat([df.pelican.idxmax(), df.pelican.max()])

# %%
df.loc['pelican.jpg'].pelican
# Out:
# mobnet    93.137902
# openv     75.396570
# Name: pelican.jpg, dtype: float64

# %%
df.pelican.mobnet[df.pelican.mobnet > 64].sort_values(ascending=False)
# Out:
# pelican.jpg    93.137902
# 131.0.jpg      66.955274
# 289.0.jpg      64.729404
# 365.0.jpg      64.684266
# 25.0.jpg       64.520812
# Name: mobnet, dtype: float64

# %%
df.pelican.openv[df.pelican.openv > 56].sort_values(ascending=False)
# Out:
# pelican.jpg    75.39657
# 705.0.jpg      61.48588
# 365.0.jpg      56.31559
# Name: openv, dtype: float64

# %% [markdown]
# # vistas

# %%
vistas_test_img_path = 'unpack_archive\\vistas_test.jpg'
display(Image(vistas_test_img_path))

# %%
vistas_img_path = 'unpack_archive\\zip\\vistas.jpg'
display(Image(vistas_img_path))

# %%
result_vistas = pd.concat([df.vistas.idxmax(), df.vistas.max()])

# %%
df.loc['vistas.jpg'].vistas
# Out:
# mobnet    91.16978
# openv     78.02629
# Name: vistas.jpg, dtype: float64

# %%
df.vistas.mobnet[df.vistas.mobnet > 59].sort_values(ascending=False)
# Out:
# vistas.jpg    91.169780
# 665.0.jpg     61.201185
# 34.0.jpg      59.955019
# Name: mobnet, dtype: float64

# %%
df.vistas.openv[df.vistas.openv > 47].sort_values(ascending=False)
# Out:
# vistas.jpg    78.026290
# 656.0.jpg     57.168450
# 539.0.jpg     47.477818
# Name: openv, dtype: float64

# %%
result_list = [result_cave_jolimont, result_corton, result_guillaume, result_hofer, result_lacroix, result_ladybird,
               result_monplezy, result_pelican, result_vistas]

# %%
pd.DataFrame(pd.concat(result_list)).loc['mobnet']
# Out:
#                         0
# mobnet  cave_jolimont.jpg
# mobnet           91.96189
# mobnet         corton.jpg
# mobnet          96.322286
# mobnet      guillaume.jpg
# mobnet          96.559483
# mobnet          hofer.png
# mobnet          97.731453
# mobnet        lacroix.jpg
# mobnet          96.067357
# mobnet       ladybird.jpg
# mobnet          92.911434
# mobnet       monplezy.jpg
# mobnet          96.504343
# mobnet        pelican.jpg
# mobnet          93.137902
# mobnet         vistas.jpg
# mobnet           91.16978

# %%
pd.DataFrame(pd.concat(result_list)).loc['openv']
# Out:
#                        0
# openv  cave_jolimont.jpg
# openv          63.774235
# openv         corton.jpg
# openv           73.83406
# openv      guillaume.jpg
# openv            97.0085
# openv          hofer.png
# openv          78.641365
# openv        lacroix.jpg
# openv           88.78467
# openv       ladybird.jpg
# openv          82.836876
# openv       monplezy.jpg
# openv            93.5013
# openv        pelican.jpg
# openv           75.39657
# openv         vistas.jpg
# openv           78.02629
